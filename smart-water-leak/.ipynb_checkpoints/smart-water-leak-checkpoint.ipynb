# %% [markdown]
# # Smart Water Leak Detection

# %% [markdown]
# This notebook is created by Butial, Aivann Paul.

# %% [markdown]
# * The [Smart Water Leak Detection](https://www.kaggle.com/datasets/talha97s/smart-water-leak-detection-dataset) is available in Kaggle.
# * The objectives of this project are to perform data cleaning and preprocessing, exploratory data analysis, implement simple ML models (`Decision Tree`, `Logistic Regression`, and `K-Nearest Neighbor`), and compare their performance.

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Model Training

# %% [markdown]
# ## Results
